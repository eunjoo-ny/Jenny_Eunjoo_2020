# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os


# %matplotlib inline

loansData=pd.read_csv('loansData.csv',header=0, sep=',')

# %%
loansData
# Out:
#        Amount.Requested  Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 81174             20000                    20000.00         8.90%   36 months
# 99592             19200                    19200.00        12.12%   36 months
# 80059             35000                    35000.00        21.98%   60 months
# 15825             10000                     9975.00         9.99%   36 months
# 33182             12000                    12000.00        11.71%   36 months
# ...                 ...                         ...           ...         ...
# 23735             30000                    29950.00        16.77%   60 months
# 65882             16000                    16000.00        14.09%   60 months
# 55610             10000                    10000.00        13.99%   36 months
# 38576              6000                     6000.00        12.42%   36 months
# 3116               9000                     5242.75        13.79%   36 months
#
# ...

# %%
loansData
# Out:
#        Amount.Requested  Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 81174             20000                    20000.00         8.90%   36 months
# 99592             19200                    19200.00        12.12%   36 months
# 80059             35000                    35000.00        21.98%   60 months
# 15825             10000                     9975.00         9.99%   36 months
# 33182             12000                    12000.00        11.71%   36 months
# ...                 ...                         ...           ...         ...
# 23735             30000                    29950.00        16.77%   60 months
# 65882             16000                    16000.00        14.09%   60 months
# 55610             10000                    10000.00        13.99%   36 months
# 38576              6000                     6000.00        12.42%   36 months
# 3116               9000                     5242.75        13.79%   36 months
#
# ...

# %%
cwd = os.getcwd()

datadir= '/'.join(cwd.split('/')[0:-1]) + '/data/'

print ("Column Name Are:")
print ("")

for column_name in loansData.columns.values:
    print( column_name)
    
print("")
print('Total #of Columns ={}'.format(len(loansData.columns)))
print('Total #of Rows ={}'.format(len(loansData.rows)))
# Out:
# Column Name Are:
#
# Amount.Requested
# Amount.Funded.By.Investors
# Interest.Rate
# Loan.Length
# Loan.Purpose
# Debt.To.Income.Ratio
# State
# Home.Ownership
# Monthly.Income
# FICO.Range
# Open.CREDIT.Lines
# Revolving.CREDIT.Balance
# Inquiries.in.the.Last.6.Months
# Employment.Length
#
# Total #of Columns =14
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0d679b64f665> in <module>
#      11 print("")
#      12 print('Total #of Columns ={}'.format(len(loansData.columns)))
# ---> 13 print('Total #of Rows ={}'.format(len(loansData.rows)))
#      14
#      15
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5134             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5135                 return self[name]
# -> 5136             return object.__getattribute__(self, name)
#    5137
# ...

# %%
loansData.head().transpose()
# Out:
#                                              81174               99592  \
# Amount.Requested                             20000               19200
# Amount.Funded.By.Investors                   20000               19200
# Interest.Rate                                8.90%              12.12%
# Loan.Length                              36 months           36 months
# Loan.Purpose                    debt_consolidation  debt_consolidation
# Debt.To.Income.Ratio                        14.90%              28.36%
# State                                           SC                  TX
# Home.Ownership                            MORTGAGE            MORTGAGE
# Monthly.Income                             6541.67             4583.33
# FICO.Range                                 735-739             715-719
# Open.CREDIT.Lines                               14                  12
# Revolving.CREDIT.Balance                     14272               11140
# ...

# %%
loansData.describe().transpose()
# Out:
#                                  count          mean           std      min  \
# Amount.Requested                2500.0  12406.500000   7801.544872  1000.00
# Amount.Funded.By.Investors      2500.0  12001.573236   7745.320754    -0.01
# Monthly.Income                  2499.0   5688.931321   3963.118185   588.50
# Open.CREDIT.Lines               2498.0     10.075661      4.508644     2.00
# Revolving.CREDIT.Balance        2498.0  15244.559648  18308.549795     0.00
# Inquiries.in.the.Last.6.Months  2498.0      0.906325      1.231036     0.00
#
#                                     25%      50%       75%       max
# Amount.Requested                6000.00  10000.0  17000.00   35000.0
# Amount.Funded.By.Investors      6000.00  10000.0  16000.00   35000.0
# Monthly.Income                  3500.00   5000.0   6800.00  102750.0
# Open.CREDIT.Lines                  7.00      9.0     13.00      38.0
# Revolving.CREDIT.Balance        5585.75  10962.0  18888.75  270800.0
# ...

# %%
loansData['Monthly.Income'][0:5]
#should be solved: index number
# Out:
# 81174     6541.67
# 99592     4583.33
# 80059    11500.00
# 15825     3833.33
# 33182     3195.00
# Name: Monthly.Income, dtype: float64

# %%
loansData['Monthly.Income'][0:5].index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d42c9735f1b9> in <module>
# ----> 1 loansData['Monthly.Income'][0:5].index()
#
# TypeError: 'Int64Index' object is not callable

# %%
plt.figure()
hist_inc = loansData['Monthly.Income'].hist()
plt.title('Histogram of Monthly Income')
plt.show()

# %%
loansData['Monthly.LogIncome']=np.log(loansData['Monthly.Income'])
plt.figure()
h = loansData['Monthly.LogIncome'].hist()
plt.title('Historgram of Log(Monthly Income)')
plt.show()

# %%
len(loansData)
# Out:
# 2500

# %%
print("Cardinality of Interest.Rate={}".format(loansData['Interest.Rate'].
                                              describe()['unique']))
print("Cardinality of FICO.Range={}".format(loansData['FICO.Range'].describe()['unique']))
# Out:
# Cardinality of Interest.Rate=275
# Cardinality of FICO.Range=38

# %%
#Student input code here - show the field type
type(loansData['Interest.Rate'][81174])
# Out:
# str

# %%
loansData_sorted_by_index=loansData.sort_index(ascending=True)

# %%
loansData_index=loansData.reset_index(drop=False, inplace=False)
loansData_index
# Out:
#       index  Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 0     81174             20000                    20000.00         8.90%
# 1     99592             19200                    19200.00        12.12%
# 2     80059             35000                    35000.00        21.98%
# 3     15825             10000                     9975.00         9.99%
# 4     33182             12000                    12000.00        11.71%
# ...     ...               ...                         ...           ...
# 2495  23735             30000                    29950.00        16.77%
# 2496  65882             16000                    16000.00        14.09%
# 2497  55610             10000                    10000.00        13.99%
# 2498  38576              6000                     6000.00        12.42%
# 2499   3116              9000                     5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
loansData_sorted_by_index2=loansData.sort_index(ascending=False)

loansData_sorted_by_index2
# Out:
#         Amount.Requested  Amount.Funded.By.Investors Interest.Rate  \
# 104202              8000                     8000.00        15.57%
# 104166              8000                     8000.00        14.83%
# 104101              9500                     6500.00         6.54%
# 104069             10000                     9875.00        14.09%
# 104040              6000                     6000.00        10.75%
# ...                  ...                         ...           ...
# 224                24625                      917.28        14.07%
# 132                12375                      275.00        10.91%
# 63                 18500                     3100.00        15.33%
# 17                  5400                      200.00         7.75%
# 10                  5000                      525.00         9.33%
#
#        Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 104202   60 months      major_purchase                2.38%    IL
# ...

# %%
type(loansData_index['Interest.Rate'][0])
# Out:
# str

# %%
loansData_index.loc[:,'Interest.Rate'][0]
# Out:
# '8.90%'

# %%
loansData_index['Monthly.Income'][0:5]
# Out:
# 0     6541.67
# 1     4583.33
# 2    11500.00
# 3     3833.33
# 4     3195.00
# Name: Monthly.Income, dtype: float64

# %%
plt.figure()
hist_inc=loansData_index['Monthly.Income'].hist()
plt.title('Histogram of Monthly Income')
plt.show()

# %%
loansData_index['Monthly.LogIncome']=np.log(loansData_index['Monthly.Income'])
plt.figure()
hist_inc=loansData_index['Monthly.LogIncome'].hist()
plt.title('Histogram of Monthly Income')
plt.show()

# %%
loansData['Interest.Rate.Num']=loansData['Interest.Rate'].str.strip('%').astype(float)

# %%
plt.scatter(loansData['Monthly.Income'], loansData['Amount.Requested'])

# %%
loansData['Monthly.LogIncome']=np.log(loansData['Monthly.Income'])

plt.scatter(loansData['Monthly.LogIncome'], loansData['Amount.Requested'])

# %%
loansData_index.loc[:,'Interest.Rate'][0]
# Out:
# '8.90%'

# %%
fico_grp=loansData[['Interest.Rate.Num','FICO.Range']].groupby(['FICO.Range']).mean().reset_index()
# Out:
#    FICO.Range  Interest.Rate.Num
# 0     640-644          15.212000
# 1     645-649          14.883333
# 2     650-654          15.130000
# 3     655-659          14.930000
# 4     660-664          18.492480
# 5     665-669          17.448069
# 6     670-674          16.248480
# 7     675-679          15.854699
# 8     680-684          15.126688
# 9     685-689          14.654855
# 10    690-694          14.732071
# 11    695-699          14.146863
# 12    700-704          13.356870
# 13    705-709          12.659851
# 14    710-714          12.433125
# 15    715-719          11.181935
# 16    720-724          11.035789
# 17    725-729          10.652979
# 18    730-734           9.956170
# 19    735-739           9.623538
# 20    740-744           9.592264
# 21    745-749           9.901667
# 22    750-754           8.467705
# 23    755-759           8.996087
# 24    760-764           8.627609
# 25    765-769           7.783333
# 26    770-774           6.752941
# ...

# %%
plt.scatter(fico_grp_noindex.index,fico_grp['Interest.Rate.Num'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-76bc12a34829> in <module>
# ----> 1 plt.scatter(fico_grp_noindex.index,fico_grp['Interest.Rate.Num'])
#
# NameError: name 'fico_grp_noindex' is not defined
